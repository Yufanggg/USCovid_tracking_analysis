# %%
#!pip install ipython-sql
# %load_ext sql
# %sql sqlite:///./Save/us_covid.db
# Out:
# Connecting to 'sqlite:///./Save/us_covid.db'

# %%
# %%sql
# SELECT * FROM UScovid_tracking
# Out:
# Running query in 'sqlite:///./Save/us_covid.db'
# +-------+----------------------------+--------+------------+------------+---------+-----------------------+------------------------+----------------+-----------------+-----------------------+------------------------+----------------------+----------+--------------+------------------+----------------------+-----------+-------+--------+---------------+----------------------+------------------+------------------+--------------------------+
# | index |            date            | states |  positive  |  negative  | pending | hospitalizedCurrently | hospitalizedCumulative | inIcuCurrently | inIcuCumulative | onVentilatorCurrently | onVentilatorCumulative |     dateChecked      |  death   | hospitalized | totalTestResults |     lastModified     | recovered | total | posNeg | deathIncrease | hospitalizedIncrease | negativeIncrease | positiveIncrease | totalTestResultsIncrease |
# ...

# %%
# %%sql
# SELECT date, death, hospitalizedCurrently, inIcuCurrently, negative, positive
#   FROM UScovid_tracking
#   LIMIT 5
# Out:
# Running query in 'sqlite:///./Save/us_covid.db'
# +----------------------------+----------+-----------------------+----------------+------------+------------+
# |            date            |  death   | hospitalizedCurrently | inIcuCurrently |  negative  |  positive  |
# +----------------------------+----------+-----------------------+----------------+------------+------------+
# | 2021-03-07 00:00:00.000000 | 515151.0 |        40199.0        |     8134.0     | 74582825.0 | 28756489.0 |
# | 2021-03-06 00:00:00.000000 | 514309.0 |        41401.0        |     8409.0     | 74450990.0 | 28714654.0 |
# | 2021-03-05 00:00:00.000000 | 512629.0 |        42541.0        |     8634.0     | 74307155.0 | 28654639.0 |
# | 2021-03-04 00:00:00.000000 | 510408.0 |        44172.0        |     8970.0     | 74035238.0 | 28585852.0 |
# | 2021-03-03 00:00:00.000000 | 508665.0 |        45462.0        |     9359.0     | 73857281.0 | 28520365.0 |
# ...

# %%
# %%sql
# SELECT date, death, hospitalizedCurrently, inIcuCurrently, negative, positive
#   FROM UScovid_tracking_null_non_null
#   LIMIT 5
# Out:
# Running query in 'sqlite:///./Save/us_covid.db'
# +----------------------------+-------+-----------------------+----------------+----------+----------+
# |            date            | death | hospitalizedCurrently | inIcuCurrently | negative | positive |
# +----------------------------+-------+-----------------------+----------------+----------+----------+
# | 2021-03-07 00:00:00.000000 |   1   |           1           |       1        |    1     |    1     |
# | 2021-03-06 00:00:00.000000 |   1   |           1           |       1        |    1     |    1     |
# | 2021-03-05 00:00:00.000000 |   1   |           1           |       1        |    1     |    1     |
# | 2021-03-04 00:00:00.000000 |   1   |           1           |       1        |    1     |    1     |
# | 2021-03-03 00:00:00.000000 |   1   |           1           |       1        |    1     |    1     |
# +----------------------------+-------+-----------------------+----------------+----------+----------+
